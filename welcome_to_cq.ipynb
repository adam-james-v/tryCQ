# %% [markdown]
# <div class="clearfix" style="padding: 10px; padding-left: 10px">
# <img src="https://raw.githubusercontent.com/jupyter/nature-demo/master/images/jupyter-logo.png" width="150px" style="display: inline-block; margin-top: 5px;">
# <a href="http://bit.ly/tmpnbdevrax"><img src="https://dcowden.github.io/cadquery/_static/cqlogo.png" width="150px" class="pull-right" style="display: inline-block; margin: 0px;"></a>
# </div>
#
# ## Try CadQuery on a Temporary Notebook!
#
# This Notebook Server was **launched just for you**. It's purpose is to allow you to try out CadQuery before you decide to set it up for yourself. There are several different methods for using CadQuery in addition to using them inside Jupyter notebooks, but the philosphy behind Jupyter fits nicely with what CadQuery aims to achieve. As such, we hope you enjoy using it here!
#
# <div class="alert alert-warning" role="alert" style="margin: 10px">
# <p>**ATTENTION**</p>
#
# <p>Don't rely on this server for anything you want to last - your server will be *deleted after a few minutes of inactivity*.</p>
# </div>
#
# Your server is hosted on a [DigitalOcean](digitalocean.com) droplet and is administered by [Adam Vermeer](https://twitter.com/rustyvermeer).
#
# It's a humble setup, so please be patient if something is amiss. Feel free to do any of the following if you notice something wrong or just wish to give some (constructive) feedback:
#
# * post an issue on Github (repo coming soon)
# * head to the [CadQuery Forum](https://groups.google.com/forum/#!forum/cadquery) and read / post there. There are several helpful folks over there.
# * [reach Adam on Twitter](https://twitter.com/rustyvermeer) and send a message and/or tweet, if you'd like.
#
# <div class="alert alert-warning" role="alert" style="margin: 10px">
# <p>**ONE FINAL NOTE**</p>
#
# <p>This server is set up using the tmpnb repository as a base. There is ongoing work in the Jupyter community to build a more sensible and reliable replacement for this technology. As such, this server is provided as is with the knowledge that soon there will be a more preferred method of setup. If the server goes down, please be patient as this transition to newer technology may take some time.</p>
# </div>
#
# ## Sources and Credit
#
# * Server is using the [tmpnb](https://github.com/jupyter/tmpnb) technology. [Contributers](https://github.com/jupyter/tmpnb/graphs/contributors)
# * TryCadquery.com is launching temporary docker containers using a custom image heavily based upon the [Jupyter/demo](https://hub.docker.com/r/jupyter/demo/) image.
# * [CadQuery](https://github.com/dcowden/cadquery) is the library being demoed. [Contributers](https://github.com/dcowden/cadquery/graphs/contributors). It is currently using [FreeCAD](https://www.freecadweb.org/) as the backend.
# * [CQNB](https://github.com/RustyVermeer/cqnb) is the module that allows Jupyter Notebooks to display CadQuery scripts. It relies upon:
#     * [pythreejs](https://github.com/jovyan/pythreejs). [Contributers](https://github.com/jovyan/pythreejs/graphs/contributors)
#     * [ipywidgets](https://github.com/jupyter-widgets/ipywidgets). [Contributers](https://github.com/jupyter-widgets/ipywidgets/graphs/contributors)
#
# Some of the content within this notebook is based on the notebook [here](https://github.com/jupyter/docker-demo-images/blob/master/notebooks/Welcome%20to%20Python.ipynb).
#
# The example notebooks are all taken from the [CadQuery example scripts](https://github.com/dcowden/cadquery/tree/master/examples/FreeCAD), which have been compiled over time by various users and contributers.
#
# Many thanks to the efforts of all people involved with each part of this. :)

# %% [markdown]
# ## Totally new to Jupyter?
#
# Don't worry, the basics are nice and simple to grasp :).
#
# Jupyter's main page provides a file browser, allowing you to select folders and files. The most interesting of which are *notebook* files with the file extension **.ipynb**. You're interacting with one such file now, in fact.
#
# Inside a notebook you have a view of *cells* which can contain either text or code. This cell is a *markdown* cell used for inline explanations and documentation. The cell below is a *code* cell, which is interpreted by the **kernel** as python code. If you ever set up your own installation, you will have the ability to install different kernels that allow you to create notebooks for different languages. Powerful stuff!
#
# You can use the menus at the top of the notebook to add and change cells. Play around a bit and see what you can do!
#
# Feel free to open new cells using the plus button (<button class='fa fa-plus icon-plus btn btn-xs btn-default'></button>), or hitting shift-enter while this cell is selected.
#
# Behind the scenes, the software that powers this is [tmpnb](https://github.com/jupyter/tmpnb), a  Tornado application that spawns [pre-built Docker containers](https://github.com/ipython/docker-notebook) and then uses the [jupyter/configurable-http-proxy](https://github.com/jupyter/configurable-http-proxy) to put your notebook server on a unique path.
#
# ## Totally new to CadQuery?
#
# That's cool, too. It's a good thing you're here, then!
#
# Have a look through the examples folder to get a hang of the library.
# In order to get a nice display of the geometry, you'll have to follow this simple sequence of steps:
#
# 1. Highlight the cell containing the CadQuery (often shortened to CQ) script.
# 2. Press CTRL + ENTER or hit the RUN button.
# 3. Once the cell is run, you'll see a few boxes input boxes that appear alongside a *Run Interact* button. Click the button.
# 4. Have a look at your Geometry! Scroll wheel will zoom in and out. Hold Left click and drag to rotate the object around. Hold Right Click and drag to shift the frame.
# 5. Change values around in the inputs and press *Run Interact* again to regenerate a new geometry. Re-run the cell to reset everything.
#
# <video style="margin-left: 0;" width="628" height="780" controls loop src="resources/use_cq.mp4" type="video/mp4"></video>
#
# Once you can see some output, you'll likely want to try writing your own script. The best resource for learning the various functions of CadQuery is the [documentation](http://dcowden.github.io/cadquery/index.html).
#
# There's always room to improve the documentation, of course so if you run into confusion or lack of documentation, your next best bet is to [dive into the code](https://github.com/dcowden/cadquery). It's well written, so we hope you'll be able to grasp the details well enough to proceed.
#
# As always, feel free to provide feedback. Contribution from everyone makes the open source community extremely valuable. We love working together!
